# %%
import psycopg2
import configparser
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Connect to Postgresql
# Connect to Postgresql
params = configparser.ConfigParser()
params.read("database.ini")
conn = psycopg2.connect(
    database=params['postgresql']['database'],
    host=params['postgresql']['host'],
    user=params['postgresql']['user'],
    password=params['postgresql']['password'],
    port=params['postgresql']['port']
)

# %%
# Get data from table responders
sql = "SELECT * FROM responders"
df = pd.read_sql_query(sql, conn)

# %%
# Check data
df
# Out:
#      responder_id   age  gender    income            education marital_status  \
# 0               1  25.0  Female   50000.0    Bachelor's Degree         Single
# 1               2  30.0    Male  100000.0      Master's Degree        Married
# 2               3  35.0  Female   75000.0            Doctorate        Married
# 3               4  40.0    Male  125000.0  High School Diploma         Single
# 4               5  45.0  Female  100000.0    Bachelor's Degree        Married
# ..            ...   ...     ...       ...                  ...            ...
# 159           160  29.0  Female   27500.0  High School Diploma         Single
# 160           161  34.0    Male   47500.0   Associate's Degree         Single
# 161           162  39.0  Female   62500.0    Bachelor's Degree        Married
# 162           163  44.0    Male   87500.0      Master's Degree         Single
# 163           164  49.0  Female   77500.0            Doctorate        Married
#
#      number_of_children home_ownership credit_score
# 0                   0.0         Rented         High
# 1                   2.0          Owned         High
# 2                   1.0          Owned         High
# 3                   0.0          Owned         High
# 4                   3.0          Owned         High
# ..                  ...            ...          ...
# 159                 0.0         Rented          Low
# 160                 0.0         Rented      Average
# 161                 2.0          Owned         High
# 162                 0.0          Owned         High
# 163                 1.0          Owned         High
#
# [164 rows x 9 columns]

# %%
# Get Column Information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 164 entries, 0 to 163
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   responder_id        164 non-null    int64
#  1   age                 164 non-null    float64
#  2   gender              164 non-null    object
#  3   income              164 non-null    float64
#  4   education           164 non-null    object
#  5   marital_status      164 non-null    object
#  6   number_of_children  164 non-null    float64
#  7   home_ownership      164 non-null    object
#  8   credit_score        164 non-null    object
# dtypes: float64(3), int64(1), object(5)
# memory usage: 8.4+ KB

# %%
# Type credit score
df['credit_score'].unique()
# Gender responder
df['credit_score'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
#Check Null Value
df.isnull().sum()
# Out:
# responder_id          0
# age                   0
# gender                0
# income                0
# education             0
# marital_status        0
# number_of_children    0
# home_ownership        0
# credit_score          0
# dtype: int64

# %%
# Gender responder
df['gender'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
# Marital status responder
df['marital_status'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df.groupby(['gender'])['credit_score'].value_counts().unstack().plot(kind ='bar')
# Out:
# <AxesSubplot:xlabel='gender'>

# %%
sns.displot(df, x="marital_status", hue="credit_score")

# %%
sns.displot(df, x="home_ownership", hue="credit_score")

# %%
sns.displot(df, x="age", hue="credit_score", kind='kde')

# %%
sns.displot(df, x="income", hue="credit_score", kind='kde')

# %%
sns.pairplot(data=df.iloc[:,1:], hue='credit_score')
# Out:
# c:\Users\ASUS\AppData\Local\Programs\Python\Python37-32\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
